# %% [markdown]
# ### Task-1:

# %%
import cv2
import numpy as np
from PIL import Image

img = cv2.imread('pic1.png',0)
kernel = np.ones((3,3),np.uint8)
erosion1 = cv2.erode(img,kernel,iterations = 1)
erosion2 = cv2.erode(img,kernel,iterations = 2)

dilation1 = cv2.dilate(img, kernel, iterations=1) 
dilation2 = cv2.dilate(img, kernel, iterations=2)

print('Erosion Iteration 1')
display(Image.fromarray(erosion1))
print('Erosion Iteration 2')
display(Image.fromarray(erosion2))
print('Dilation Iteration 1')
display(Image.fromarray(dilation1))
print('Dilation Iteration 2')
display(Image.fromarray(dilation2))
# Out:
# Erosion Iteration 1
# <PIL.Image.Image image mode=L size=747x301 at 0x16976330320>
# Erosion Iteration 2
# <PIL.Image.Image image mode=L size=747x301 at 0x16976330400>
# Dilation Iteration 1
# <PIL.Image.Image image mode=L size=747x301 at 0x16976330278>
# Dilation Iteration 2
# <PIL.Image.Image image mode=L size=747x301 at 0x16976330400>

# %% [markdown]
# ### Task-2:

# %%
img = cv2.imread('pic2.png',0)
ret,thresh1 = cv2.threshold(img,40,255,cv2.THRESH_BINARY)
display(Image.fromarray(thresh1))
kernel = np.ones((5,5),np.uint8)
merode = cv2.erode(thresh1,kernel,iterations = 3)
display(Image.fromarray(merode))
# Out:
# <PIL.Image.Image image mode=L size=587x309 at 0x169762EF940>
# <PIL.Image.Image image mode=L size=587x309 at 0x169762EF438>
